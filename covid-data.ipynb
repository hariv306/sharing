# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("time_series_covid19_confirmed_global.csv", index_col= None, na_values=["N/A"]) #read csv from dataframe

print(df)
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 269            NaN             Vietnam  14.058324  108.277199        0
# 270            NaN  West Bank and Gaza  31.952200   35.233200        0
# 271            NaN               Yemen  15.552727   48.516388        0
# 272            NaN              Zambia -13.133897   27.849332        0
# 273            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/20/21  2/21/21  \
# ...

# %%
df2= df1.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e1595aec4196> in <module>
# ----> 1 df2= df1.T
#
# NameError: name 'df1' is not defined

# %%
df.drop(["Lat",
        "Long"],axis=1)
# Out:
#     Province/State      Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN         Afghanistan        0        0        0        0
# 1              NaN             Albania        0        0        0        0
# 2              NaN             Algeria        0        0        0        0
# 3              NaN             Andorra        0        0        0        0
# 4              NaN              Angola        0        0        0        0
# ..             ...                 ...      ...      ...      ...      ...
# 269            NaN             Vietnam        0        2        2        2
# 270            NaN  West Bank and Gaza        0        0        0        0
# 271            NaN               Yemen        0        0        0        0
# 272            NaN              Zambia        0        0        0        0
# 273            NaN            Zimbabwe        0        0        0        0
#
# ...

# %%
df=df.drop(["Lat",
        "Long"],axis=1)

# %%
df2=df.T
print(df2.head(3))
# Out:
#                         0        1        2        3       4    \
# Province/State          NaN      NaN      NaN      NaN     NaN
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola
# 1/22/20                   0        0        0        0       0
#
#                                 5          6        7    \
# Province/State                  NaN        NaN      NaN
# Country/Region  Antigua and Barbuda  Argentina  Armenia
# 1/22/20                           0          0        0
#
#                                          8                9    ...  \
# Province/State  Australian Capital Territory  New South Wales  ...
# Country/Region                     Australia        Australia  ...
# 1/22/20                                    0                0  ...
#
#                            264      265         266      267        268  \
# Province/State             NaN      NaN         NaN      NaN        NaN
# ...

# %%
pd.DataFrame(df2)
# Out:
#                         0        1        2        3       4    \
# Province/State          NaN      NaN      NaN      NaN     NaN
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# ...                     ...      ...      ...      ...     ...
# 2/25/21               55680   104313   112622    10799   20695
# 2/26/21               55696   105229   112805    10822   20759
# 2/27/21               55707   106215   112960    10849   20782
# 2/28/21               55714   107167   113092    10866   20807
# 3/1/21                55733   107931   113255    10889   20854
#
#                                 5          6        7    \
# Province/State                  NaN        NaN      NaN
# Country/Region  Antigua and Barbuda  Argentina  Armenia
# ...

# %%
export_file_path = filedialog.asksaveasfilename(defaultextension='.xlsx')
    df.to_excel ("C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1", index = False, header=True)

saveAsButtonExcel = tk.Button(text='Export Excel', command=exportExcel, bg='green', fg='white', font=('helvetica', 12, 'bold'))
canvas1.create_window(150, 150, window=saveAsButtonExcel)
# Out:
#   File "<ipython-input-9-9a1a51d03550>", line 2
#     df.to_excel ("C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1", index = False, header=True)
#     ^
# IndentationError: unexpected indent

# %%
export_file_path = filedialog.asksaveasfilename(defaultextension='.xlsx')
df.to_excel ("C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1", index = False, header=True)

saveAsButtonExcel = tk.Button(text='Export Excel', command=exportExcel, bg='green', fg='white', font=('helvetica', 12, 'bold'))
canvas1.create_window(150, 150, window=saveAsButtonExcel)
# Out:
#   File "<ipython-input-10-3bfbf7581f4d>", line 2
#     df.to_excel ("C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1", index = False, header=True)
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
root= df.Tk()

canvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue2', relief = 'raised')
canvas1.pack()

def exportExcel ():
    global df
    
    export_file_path = filedialog.asksaveasfilename(defaultextension='.xlsx')
    df.to_excel (export_file_path, index = False, header=True)

saveAsButtonExcel = tk.Button(text='Export Excel', command=exportExcel, bg='green', fg='white', font=('helvetica', 12, 'bold'))
canvas1.create_window(150, 150, window=saveAsButtonExcel)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5ed8d3fc298d> in <module>
# ----> 1 root= df.Tk()
#       2
#       3 canvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue2', relief = 'raised')
#       4 canvas1.pack()
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Tk'

# %%
import pandas as pd

read_file = pd.read_csv (r"time_series_covid19_confirmed_global.csv")
read_file.to_excel (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\file1.xlsx', index = None, header=True)

# %%
df.to_excel (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\file2.xlsx', index = None, header=True)

# %%
df= df.drop(["Province/State"],axis=1)

print(df)
# Out:
#          Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0           Afghanistan        0        0        0        0        0        0
# 1               Albania        0        0        0        0        0        0
# 2               Algeria        0        0        0        0        0        0
# 3               Andorra        0        0        0        0        0        0
# 4                Angola        0        0        0        0        0        0
# ..                  ...      ...      ...      ...      ...      ...      ...
# 269             Vietnam        0        2        2        2        2        2
# 270  West Bank and Gaza        0        0        0        0        0        0
# 271               Yemen        0        0        0        0        0        0
# 272              Zambia        0        0        0        0        0        0
# 273            Zimbabwe        0        0        0        0        0        0
#
# ...

# %%
df.to_excel (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\file1.xlsx', index = None, header=True)

# %%
df3= df.groupby("Country/Region")

print(df3)

# %%
print(df.head(3))
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  2/20/21  2/21/21  2/22/21  2/23/21  \
# 0        0        0        0  ...    55580    55604    55617    55646
# 1        0        0        0  ...    99062   100246   101285   102306
# 2        0        0        0  ...   111764   111917   112094   112279
#
#    2/24/21  2/25/21  2/26/21  2/27/21  2/28/21  3/1/21
# 0    55664    55680    55696    55707    55714   55733
# 1   103327   104313   105229   106215   107167  107931
# 2   112461   112622   112805   112960   113092  113255
#
# [3 rows x 406 columns]

# %%
df4=df.groupby('Country/Region').agg({"sum"})

# %%
df4=pd.DataFrame(df4)
print(df4.head(3))
# Out:
#                1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20  \
#                    sum     sum     sum     sum     sum     sum     sum
# Country/Region
# Afghanistan          0       0       0       0       0       0       0
# Albania              0       0       0       0       0       0       0
# Algeria              0       0       0       0       0       0       0
#
#                1/29/20 1/30/20 1/31/20  ... 2/20/21 2/21/21 2/22/21 2/23/21  \
#                    sum     sum     sum  ...     sum     sum     sum     sum
# Country/Region                          ...
# Afghanistan          0       0       0  ...   55580   55604   55617   55646
# Albania              0       0       0  ...   99062  100246  101285  102306
# Algeria              0       0       0  ...  111764  111917  112094  112279
#
#                2/24/21 2/25/21 2/26/21 2/27/21 2/28/21  3/1/21
#                    sum     sum     sum     sum     sum     sum
# Country/Region
# ...

# %%
df4=pd.DataFrame(df4)

# %%
print(df4)
# Out:
#                    1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20  \
#                        sum     sum     sum     sum     sum     sum     sum
# Country/Region
# Afghanistan              0       0       0       0       0       0       0
# Albania                  0       0       0       0       0       0       0
# Algeria                  0       0       0       0       0       0       0
# Andorra                  0       0       0       0       0       0       0
# Angola                   0       0       0       0       0       0       0
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam                  0       2       2       2       2       2       2
# West Bank and Gaza       0       0       0       0       0       0       0
# Yemen                    0       0       0       0       0       0       0
# Zambia                   0       0       0       0       0       0       0
# ...

# %%
df4.to_excel (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project) 1\file2.xlsx', index = None, header=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-33-da2ef533636e> in <module>
# ----> 1 df4.to_excel (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project) 1\file2.xlsx', index = None, header=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2024             inf_rep=inf_rep,
#    2025         )
# -> 2026         formatter.write(
#    2027             excel_writer,
#    2028             sheet_name=sheet_name,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     732
#     733         formatted_cells = self.get_formatted_cells()
# --> 734         writer.write_cells(
# ...

# %%
df4.to_csv (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\file3.xlsx', index = None, header=True)

# %%
df4
# Out:
#                    1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20  \
#                        sum     sum     sum     sum     sum     sum     sum
# Country/Region
# Afghanistan              0       0       0       0       0       0       0
# Albania                  0       0       0       0       0       0       0
# Algeria                  0       0       0       0       0       0       0
# Andorra                  0       0       0       0       0       0       0
# Angola                   0       0       0       0       0       0       0
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam                  0       2       2       2       2       2       2
# West Bank and Gaza       0       0       0       0       0       0       0
# Yemen                    0       0       0       0       0       0       0
# Zambia                   0       0       0       0       0       0       0
# ...

# %%
df4=df.groupby('Country/Region').sum()

# %%
df4
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# Vietnam                   0        2        2        2        2        2
# West Bank and Gaza        0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
df4.to_csv (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\confirmed(csv).csv', index = True, header=True)

# %%
dfd= pd.read_csv("time_series_covid19_deaths_global.csv", index_col= None, na_values=["N/A"]) #read csv from dataframe

dfd
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 269            NaN             Vietnam  14.058324  108.277199        0
# 270            NaN  West Bank and Gaza  31.952200   35.233200        0
# 271            NaN               Yemen  15.552727   48.516388        0
# 272            NaN              Zambia -13.133897   27.849332        0
# 273            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/20/21  2/21/21  \
# ...

# %%
dfd=dfd.drop(["Province/State","Lat","Long"],axis=1) ###Delete unwanted columns
dfd
# Out:
#          Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0           Afghanistan        0        0        0        0        0        0
# 1               Albania        0        0        0        0        0        0
# 2               Algeria        0        0        0        0        0        0
# 3               Andorra        0        0        0        0        0        0
# 4                Angola        0        0        0        0        0        0
# ..                  ...      ...      ...      ...      ...      ...      ...
# 269             Vietnam        0        0        0        0        0        0
# 270  West Bank and Gaza        0        0        0        0        0        0
# 271               Yemen        0        0        0        0        0        0
# 272              Zambia        0        0        0        0        0        0
# 273            Zimbabwe        0        0        0        0        0        0
#
# ...

# %%
dfd=dfd.groupby('Country/Region').sum() ###Sum data from different provinces for total data per country
dfd
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# Vietnam                   0        0        0        0        0        0
# West Bank and Gaza        0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
dfd.to_csv (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\deaths(csv).csv', index = True, header=True) #### export as csv
df4.to_excel (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\deaths(excel).xlsx', index = True, header=True) ###export as excel for reference

# %%
dfr= pd.read_csv("time_series_covid19_recovered_global.csv", index_col= None, na_values=["N/A"]) #read csv from dataframe

dfr=dfr.drop(["Province/State","Lat","Long"],axis=1) ###Delete unwanted columns

dfr=dfr.groupby('Country/Region').sum() ###Sum data from different provinces for total data per country

dfr.to_csv (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\Step1 data cleaning\recovered(csv).csv', index = True, header=True) #### export as csv
dfr.to_excel (r'C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\Step1 data cleaning\recovered(excel).xlsx', index = True, header=True) ###export as excel for reference

# %%
l= pd.read_csv("C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\Dimension tables\Location\INSERT 1.xlsx", index_col= None, na_values=["N/A"]) #read csv from dataframe
# Out:
#   File "<ipython-input-54-c1c6f2f5e14c>", line 1
#     l= pd.read_excelUNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\Dimension tables\Location\INSERT 1.xlsx", index_col= None, na_values=["N/A"]) #read csv from dataframe
#                                                                                                                                                                      ^
# SyntaxError: unexpected character after line continuation character

# %%
l= pd.read_excel("C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\Dimension tables\Location\INSERT1.xlsx", index_col= None, na_values=["N/A"]) #read csv from dataframe
# Out:
#   File "<ipython-input-56-7b471b624e3e>", line 1
#     l= pd.read_excel("C:\UNIVERSITY\Year 2\Sem 1\CITS3401\Project 1\Dimension tables\Location\INSERT1.xlsx", index_col= None, na_values=["N/A"]) #read csv from dataframe
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
